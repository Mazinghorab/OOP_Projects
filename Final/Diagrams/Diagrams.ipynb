# %% [markdown]
# ![Use Case Diagram](UseCase-1.png)

# %% [markdown]
# ![Class Diagrams](Class-1.png)
# ![Class Diagrams](Class-2.png)

# %% [markdown]
# ![Activity Diagram](Activity-1.png)

# %% [markdown]
# ![Sequence Diagram](Sequence-1.png)
